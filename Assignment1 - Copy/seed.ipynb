# %%
import matplotlib.pyplot as plt
import pandas as pd
view = pd.read_csv("~/Documents/888/datasets/seeds_dataset.csv")
view.head()
# Out:
#     Area  Perimeter  Compactness  Length of kernel  Width of kernel  \
# 0  15.26      14.84       0.8710             5.763            3.312
# 1  14.88      14.57       0.8811             5.554            3.333
# 2  14.29      14.09       0.9050             5.291            3.337
# 3  13.84      13.94       0.8955             5.324            3.379
# 4  16.14      14.99       0.9034             5.658            3.562
#
#     Asymmetry Coefficient   Length of kernel groove  Classification
# 0                    2.221                    5.220               1
# 1                    1.018                    4.956               1
# 2                    2.699                    4.825               1
# 3                    2.259                    4.805               1
# 4                    1.355                    5.175               1

# %%
print(view.columns)
# Out:
# Index(['Area', 'Perimeter', 'Compactness', 'Length of kernel',
#        'Width of kernel', ' Asymmetry Coefficient ', 'Length of kernel groove',
#        'Classification'],
#       dtype='object')

# %%
view[view['Area']< 100].sample(210).plot.scatter(x='Area', y='Perimeter')
plt.title('Perimeter Vs Area of Kernel')
plt.show()

# %%
view[view['Area'] < 100].sample(210).plot.scatter(x='Area', y='Compactness')
plt.title('Compactness Vs Area of Kernel')
plt.show()

# %%
view[view['Perimeter'] < 100].sample(210).plot.scatter(x='Perimeter', y='Compactness')
plt.title('Compactness Vs Perimeter of Kernel')
plt.show()

# %%
view[view['Area'] < 100].sample(210).plot.scatter(x='Area', y='Length of kernel')
plt.title('Length of kernel Vs Area of Kernel')
plt.show()

# %%
view[view['Perimeter'] < 100].sample(210).plot.scatter(x='Perimeter', y='Length of kernel')
plt.title('Length of kernel Vs Perimeter of Kernel')
plt.show()

# %%
view[view['Perimeter'] < 100].sample(210).plot.scatter(x='Perimeter', y='Compactness')
plt.title('Compactness of kernel Vs Perimeter of Kernel')
plt.show()

# %%
view[view['Area'] < 100].sample(210).plot.scatter(x='Area', y='Compactness')
plt.title('Compactness of kernel Vs Area of Kernel')
plt.show()

# %%
view[view['Width of kernel'] < 100].sample(210).plot.scatter(x='Width of kernel', y='Length of kernel')
plt.title('Length of kernel Vs Width of kernel')
plt.show()

# %%
view[view['Area'] < 100].sample(210).plot.scatter(x='Area', y='Width of kernel')
plt.title('Width of kernel Vs Area of kernel ')
plt.show()

# %%
view[view['Width of kernel'] < 100].sample(210).plot.scatter(x='Width of kernel', y=' Asymmetry Coefficient ')
plt.title('Asymmetry Coefficient Vs Width of kernel')
plt.show()

# %%
view[view['Length of kernel'] < 100].sample(210).plot.scatter(x='Length of kernel', y=' Asymmetry Coefficient ')
plt.title('Asymmetry Coefficient Vs Length of kernel')
plt.show()

# %%
view[view['Length of kernel groove'] < 100].sample(210).plot.scatter(x='Length of kernel', y='Length of kernel groove')
plt.title('Length of kernel groove Vs Length of kernel')
plt.show()

# %%
view[view['Length of kernel groove'] < 100].sample(210).plot.scatter(x='Length of kernel groove', y=' Asymmetry Coefficient ')
plt.title(' Asymmetry Coefficient Vs Length of kernel groove')
plt.show()
