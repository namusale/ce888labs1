# %%
import matplotlib.pyplot as plt
import pandas as pd
view = pd.read_csv("~/Documents/888/datasets/dataR2.csv")
view.head()
# Out:
#    Age        BMI  Glucose  Insulin      HOMA   Leptin  Adiponectin  Resistin  \
# 0   48  23.500000       70    2.707  0.467409   8.8071     9.702400   7.99585
# 1   83  20.690495       92    3.115  0.706897   8.8438     5.429285   4.06405
# 2   82  23.124670       91    4.498  1.009651  17.9393    22.432040   9.27715
# 3   68  21.367521       77    3.226  0.612725   9.8827     7.169560  12.76600
# 4   86  21.111111       92    3.549  0.805386   6.6994     4.819240  10.57635
#
#      MCP.1  Classification
# 0  417.114               1
# 1  468.786               1
# 2  554.697               1
# 3  928.220               1
# 4  773.920               1

# %%
print(view.columns)
# Out:
# Index(['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin',
#        'Resistin', 'MCP.1', 'Classification'],
#       dtype='object')

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='BMI')
plt.title('BMI Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='Glucose')
plt.title('Glucose Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='Insulin')
plt.title('Insulin Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='HOMA')
plt.title('HOMA Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='Leptin')
plt.title('Leptin Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='Adiponectin')
plt.title('Adiponectin Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='Resistin')
plt.title('Resistin Vs Age')
plt.show()

# %%
view[view['Age']< 1000].sample(116).plot.scatter(x='Age', y='MCP.1')
plt.title('MCP.1 Vs Age')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='Glucose')
plt.title('Glucose Vs BMI')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='Insulin')
plt.title('Insulin Vs BMI')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='HOMA')
plt.title('HOMA Vs BMI')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='Leptin')
plt.title('ILeptin Vs BMI')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='Adiponectin')
plt.title('Adiponectin Vs BMI')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='Resistin')
plt.title('Resistin Vs BMI')
plt.show()

# %%
view[view['BMI']< 1000].sample(116).plot.scatter(x='BMI', y='MCP.1')
plt.title('MCP.1 Vs BMI')
plt.show()

# %%
view[view['Glucose']< 1000].sample(116).plot.scatter(x='Glucose', y='Insulin')
plt.title('Insulin Vs Glucose')
plt.show()

# %%
view[view['Glucose']< 1000].sample(116).plot.scatter(x='Glucose', y='HOMA')
plt.title('HOMA Vs Glucose')
plt.show()

# %%
view[view['Glucose']< 1000].sample(116).plot.scatter(x='Glucose', y='Leptin')
plt.title('Leptin Vs Glucose')
plt.show()

# %%
view[view['Glucose']< 1000].sample(116).plot.scatter(x='Glucose', y='Adiponectin')
plt.title('Adiponectin Vs Glucose')
plt.show()

# %%
view[view['Glucose']< 1000].sample(116).plot.scatter(x='Glucose', y='Resistin')
plt.title('Resistin Vs Glucose')
plt.show()

# %%
view[view['Glucose']< 1000].sample(116).plot.scatter(x='Glucose', y='MCP.1')
plt.title('MCP.1 Vs Glucose')
plt.show()

# %%
view[view['Insulin']< 1000].sample(116).plot.scatter(x='Insulin', y='HOMA')
plt.title('HOMA Vs Insulin')
plt.show()

# %%
view[view['Insulin']< 1000].sample(116).plot.scatter(x='Insulin', y='Leptin')
plt.title('Leptin Vs Insulin')
plt.show()

# %%
view[view['Insulin']< 1000].sample(116).plot.scatter(x='Insulin', y='Adiponectin')
plt.title('Adiponectin Vs Insulin')
plt.show()

# %%
view[view['Insulin']< 1000].sample(116).plot.scatter(x='Insulin', y='Resistin')
plt.title('Resistin Vs Insulin')
plt.show()

# %%
view[view['Insulin']< 1000].sample(116).plot.scatter(x='Insulin',y='MCP.1')
plt.title('MCP.1 Vs Insulin')
plt.show()

# %%
view[view['HOMA']< 1000].sample(116).plot.scatter(x='HOMA', y='Leptin')
plt.title('Leptin Vs HOMA')
plt.show()

# %%
view[view['HOMA']< 1000].sample(116).plot.scatter(x='HOMA', y='Adiponectin')
plt.title('Adiponectin Vs HOMA')
plt.show()

# %%
view[view['HOMA']< 1000].sample(116).plot.scatter(x='HOMA', y='Resistin')
plt.title('Resistin Vs HOMA')
plt.show()

# %%
view[view['HOMA']< 1000].sample(116).plot.scatter(x='HOMA', y='MCP.1')
plt.title('MCP.1 Vs HOMA')
plt.show()

# %%
view[view['Leptin']< 1000].sample(116).plot.scatter(x='Leptin', y='Adiponectin')
plt.title('Adiponectin Vs Leptin')
plt.show()

# %%
view[view['Leptin']< 1000].sample(116).plot.scatter(x='Leptin', y='Resistin')
plt.title('Resistin Vs Leptin')
plt.show()

# %%
view[view['Leptin']< 1000].sample(116).plot.scatter(x='Leptin', y='MCP.1')
plt.title('MCP.1 Vs Leptin')
plt.show()

# %%
view[view['Adiponectin']< 1000].sample(116).plot.scatter(x='Adiponectin', y='MCP.1')
plt.title('MCP.1 Vs Adiponectin')
plt.show()

# %%
view[view['Adiponectin']< 1000].sample(116).plot.scatter(x='Adiponectin', y='Resistin')
plt.title('Resistin Vs Adiponectin')
plt.show()

# %%
view[view['Resistin']< 1000].sample(116).plot.scatter(x='Resistin', y='MCP.1')
plt.title('Resistin Vs MCP.1')
plt.show()
