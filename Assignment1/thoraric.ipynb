# %%
import matplotlib.pyplot as plt
import pandas as pd
view = pd.read_csv("~/Documents/888/datasets/Cryotherapy.csv")
view.head()
# Out:
#    sex  age   Time  Number_of_Warts  Type  Area  Result_of_Treatment
# 0    1   35  12.00                5     1   100                    0
# 1    1   29   7.00                5     1    96                    1
# 2    1   50   8.00                1     3   132                    0
# 3    1   32  11.75                7     3   750                    0
# 4    1   67   9.25                1     1    42                    0

# %%
print(view.columns)
# Out:
# Index(['sex', 'age', 'Time', 'Number_of_Warts', 'Type', 'Area',
#        'Result_of_Treatment'],
#       dtype='object')

# %%
view[view['sex']< 100].sample(90).plot.scatter(x='sex', y='age')
plt.title('Age Vs Sex')
plt.show()

# %%
view[view['sex']< 100].sample(90).plot.scatter(x='sex', y='Time')
plt.title('Time Vs Sex')
plt.show()

# %%
view[view['sex']< 100].sample(90).plot.scatter(x='sex', y='Number_of_Warts')
plt.title('Number_of_Warts Vs Sex')
plt.show()

# %%
view[view['sex']< 100].sample(90).plot.scatter(x='sex', y='Type')
plt.title('Type_of_Warts Vs Sex')
plt.show()

# %%
view[view['sex']< 100].sample(90).plot.scatter(x='sex', y='Area')
plt.title('Area_of_Warts Vs Sex')
plt.show()

# %%
view[view['age']< 100].sample(90).plot.scatter(x='age', y='Time')
plt.title('Time Vs Age')
plt.show()

# %%
view[view['age']< 100].sample(90).plot.scatter(x='age', y='Number_of_Warts')
plt.title('Number_of_Warts Vs Age')
plt.show()

# %%
view[view['age']< 100].sample(90).plot.scatter(x='age', y='Type')
plt.title('Type_of_Warts Vs Age')
plt.show()

# %%
view[view['age']< 100].sample(90).plot.scatter(x='age', y='Area')
plt.title('Area_of_Warts Vs Age')
plt.show()

# %%
view[view['Time']< 100].sample(90).plot.scatter(x='Time', y='Number_of_Warts')
plt.title('Number_of_Warts Vs Time')
plt.show()

# %%
view[view['Time']< 100].sample(90).plot.scatter(x='Time', y='Type')
plt.title('Type_of_Warts Vs Time')
plt.show()

# %%
view[view['Time']< 100].sample(90).plot.scatter(x='Time', y='Area')
plt.title('Area Vs Time')
plt.show()

# %%
view[view['Number_of_Warts']< 100].sample(90).plot.scatter(x='Number_of_Warts', y='Type')
plt.title('Type_of_Warts Vs Number_of_Warts')
plt.show()

# %%
view[view['Number_of_Warts']< 100].sample(90).plot.scatter(x='Number_of_Warts', y='Area')
plt.title('Area_of_Warts Vs Number_of_Warts')
plt.show()

# %%
view[view['Type']< 100].sample(90).plot.scatter(x='Type', y='Area')
plt.title('Area_of_Warts Vs Type_of_Warts')
plt.show()
